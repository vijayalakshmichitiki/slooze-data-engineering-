# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/products_clean.csv")

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_name       0 non-null      float64
#  1   category           13 non-null     object
#  2   price              12 non-null     float64
#  3   supplier_name      0 non-null      float64
#  4   supplier_location  0 non-null      float64
# dtypes: float64(4), object(1)
# memory usage: 652.0+ bytes
#        product_name         price  supplier_name  supplier_location
# count           0.0  1.200000e+01            0.0                0.0
# mean            NaN  8.216268e+05            NaN                NaN
# std             NaN  1.240516e+06            NaN                NaN
# min             NaN  7.200000e+04            NaN                NaN
# 25%             NaN  1.453150e+05            NaN                NaN
# 50%             NaN  3.900000e+05            NaN                NaN
# 75%             NaN  8.625000e+05            NaN                NaN
# max             NaN  4.500000e+06            NaN                NaN

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="category", y="price", data=df)
plt.xticks(rotation=30)
plt.title("Price Distribution by Category")
plt.show()

# %%
df["supplier_location"].value_counts().head(10)
# Out:
# Series([], Name: count, dtype: int64)
